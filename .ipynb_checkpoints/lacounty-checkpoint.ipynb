# %%
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/List_of_cities_in_Los_Angeles_County,_California"
dfs = pd.read_html(url, header=0)

lacounty = dfs[0]
lacounty = lacounty[['City','Population as of (2010 Census)']]
lacounty
# Out:
#                      City  Population as of (2010 Census)
# 0            Agoura Hills                           20330
# 1                Alhambra                           83089
# 2                 Arcadia                           56364
# 3                 Artesia                           16522
# 4                  Avalon                            3728
# 5                   Azusa                           46361
# 6            Baldwin Park                           75390
# 7                    Bell                           35477
# 8            Bell Gardens                           42072
# 9              Bellflower                           76616
# 10          Beverly Hills                           34109
# 11               Bradbury                            1048
# 12                Burbank                          103340
# 13              Calabasas                           23058
# 14                 Carson                           91714
# ...

# %%
hvi = pd.read_csv("LA_County_HVI.csv")
hvi.head()
# Out:
#    RegionID   RegionName State                           Metro   CountyName  \
# 0     12447  Los Angeles    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 1     46298   Long Beach    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 2     45457     Glendale    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 3      5534    Lancaster    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 4     40227     Palmdale    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
#
#    SizeRank   1996-04   1996-05   1996-06   1996-07   ...     2017-05  \
# 0         2  155000.0  154600.0  154400.0  154200.0   ...      631500
# 1        33  148800.0  149300.0  149100.0  148400.0   ...      554500
# 2       121  202400.0  203400.0  204700.0  205400.0   ...      773000
# 3       137   92300.0   91700.0   91100.0   90600.0   ...      247200
# 4       160       NaN       NaN       NaN       NaN   ...      274100
#
#    2017-06  2017-07  2017-08  2017-09  2017-10  2017-11  2017-12  2018-01  \
# ...
