# %%
import sqlite3
import pandas as pd

# %%
sqlite_file='/Users/monaderakhshan/Git_Repo/Data_Analytics_Assignments/PROJECT 2/project2_db_TEST.sqlite'
conn = sqlite3.connect(sqlite_file)
c = conn.cursor()

# %%
c.execute('select * from us_cities')

# %%
results = c.fetchall()
results
# Out:
# [('name', 'pop', 'lat', 'lon'),
#  ('New York ', 8287238, 40.7305991, -73.9865812),
#  ('Los Angeles ', 3826423, 34.053717, -118.2427266),
#  ('Chicago ', 2705627, 41.8755546, -87.6244212),
#  ('Houston ', 2129784, 29.7589382, -95.3676974),
#  ('Philadelphia ', 1539313, 39.952335, -75.163789),
#  ('Phoenix ', 1465114, 33.4467681, -112.0756724),
#  ('San Antonio ', 1359174, 29.4246002, -98.4951405),
#  ('San Diego ', 1321016, 32.7174209, -117.1627714),
#  ('Dallas ', 1219399, 32.7761963, -96.7968994),
#  ('San Jose ', 971495, 37.3438502, -121.8831349),
#  ('Austin ', 839714, 30.2711286, -97.7436995),
#  ('Jacksonville ', 829543, 30.3321838, -81.655651),
#  ('Indianapolis  ', 827346, 39.7683331, -86.1583502),
#  ('San Francisco ', 816239, 37.7792768, -122.4192704),
#  ('Columbus ', 799270, 39.9622601, -83.0007065),
#  ('Fort Worth ', 761895, 32.753177, -97.3327459),
#  ('Charlotte ', 756204, 35.2270869, -80.8431268),
#  ('Detroit ', 702149, 42.3486635, -83.0567375),
# ...

# %%
cities_df=pd.read_sql_query('select * from us_cities',conn)
cities_df.head()
# Out:
#            city population latitude longitude
# 0          name        pop      lat       lon
# 1     New York     8287238  40.7306  -73.9866
# 2  Los Angeles     3826423  34.0537  -118.243
# 3      Chicago     2705627  41.8756  -87.6244
# 4      Houston     2129784  29.7589  -95.3677

# %%
cities_df
# Out:
#                                 city population latitude longitude
# 0                               name        pop      lat       lon
# 1                          New York     8287238  40.7306  -73.9866
# 2                       Los Angeles     3826423  34.0537  -118.243
# 3                           Chicago     2705627  41.8756  -87.6244
# 4                           Houston     2129784  29.7589  -95.3677
# 5                      Philadelphia     1539313  39.9523  -75.1638
# 6                           Phoenix     1465114  33.4468  -112.076
# 7                       San Antonio     1359174  29.4246  -98.4951
# 8                         San Diego     1321016  32.7174  -117.163
# 9                            Dallas     1219399  32.7762  -96.7969
# 10                         San Jose      971495  37.3439  -121.883
# 11                           Austin      839714  30.2711  -97.7437
# 12                     Jacksonville      829543  30.3322  -81.6557
# ...

# %%
citiesUS = cities_df.iloc[1:]
citiesUS.head()
# Out:
#             city population latitude longitude
# 1      New York     8287238  40.7306  -73.9866
# 2   Los Angeles     3826423  34.0537  -118.243
# 3       Chicago     2705627  41.8756  -87.6244
# 4       Houston     2129784  29.7589  -95.3677
# 5  Philadelphia     1539313  39.9523  -75.1638

# %%
city_name=citiesUS['city'] 
population=citiesUS['population']
latitude=citiesUS['latitude']
longitude=citiesUS['longitude']

# %%
cities=[]
for i in citiesUS.iterrows():
    city = dict(
        type = 'scattergeo',
        locationmode = 'USA-states',
        lon = citiesUS['longitude'],
        lat = citiesUS['latitude'],
        text = citiesUS['city'],
        sizemode = 'diameter',
        marker = dict( 
            size = citiesUS['population']/100000, 
            color = ['red','blue','green','yellow'],
            line = dict(width = 2,color = 'black')
        ))
    cities.append(city)

# %%
layout = dict(
        title = '2014 US city populations',
        showlegend = True,
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',       
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"           
        ),  
    )
    
fig = dict( data=cities, layout=layout )
url = py.plot( fig, validate=False, filename='d3-bubble-map-populations' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-1a08b66275d8> in <module>()
#      15
#      16 fig = dict( data=cities, layout=layout )
# ---> 17 url = py.plot( fig, validate=False, filename='d3-bubble-map-populations' )
#
# NameError: name 'py' is not defined
